# %%
import numpy as np

# %%
# MovieLens
baseline = [0.391516, 0.211452]

hard_batch_1 = [0.396076, 0.211831]
hard_batch_2 = [0.394910, 0.216197]
hard_batch_3 = [0.396607, 0.213584]

hard_epoch_1 = [0.395122, 0.211966]
hard_epoch_2 = [0.393531, 0.212037]
hard_epoch_3 = [0.394698, 0.212223]

# %%
hard_batches = np.array([hard_batch_1, hard_batch_2, hard_batch_3])

mean_precision = np.mean(hard_batches[:, 0])
std_error_precision = np.std(hard_batches[:, 0], ddof=1) / np.sqrt(len(hard_batches))

mean_recall = np.mean(hard_batches[:, 1])
std_error_recall = np.std(hard_batches[:, 1], ddof=1) / np.sqrt(len(hard_batches))

(mean_precision, std_error_precision, mean_recall, std_error_recall)
# Out:
# (0.3958643333333333,
#  0.0005011833773957182,
#  0.21387066666666665,
#  0.001268479711220398)

# %%
hard_epoches = np.array([hard_epoch_1, hard_epoch_2, hard_epoch_3])

mean_precision = np.mean(hard_epoches[:, 0])
std_error_precision = np.std(hard_epoches[:, 0], ddof=1) / np.sqrt(len(hard_epoches))

mean_recall = np.mean(hard_epoches[:, 1])
std_error_recall = np.std(hard_epoches[:, 1], ddof=1) / np.sqrt(len(hard_epoches))

(mean_precision, std_error_precision, mean_recall, std_error_recall)
# Out:
# (0.39445033333333335,
#  0.00047568348486968224,
#  0.2120753333333333,
#  7.66253511864357e-05)

# %% [markdown]
# # Train curve

# %% [markdown]
# ## Batch 1

# %%
data = """
Epoch 1 (train)5.5s: train loss = 0.40833 = (mf)0.40792 + (embed)0.00040
Epoch 2 (train)2.7s: train loss = 0.27106 = (mf)0.27021 + (embed)0.00084
Epoch 3 (train)2.5s: train loss = 0.24996 = (mf)0.24887 + (embed)0.00109
Epoch 4 (train)2.0s: train loss = 0.23369 = (mf)0.23238 + (embed)0.00130
Epoch 5 (train)1.7s + (eval)0.2s: train loss = 0.21646 = (mf)0.21494 + (embed)0.00152, recall = 0.17201, ndcg = 0.37471, precision = 0.32587, map = 0.10313
Epoch 6 (train)1.9s: train loss = 0.20597 = (mf)0.20422 + (embed)0.00175
Epoch 7 (train)1.7s: train loss = 0.19467 = (mf)0.19270 + (embed)0.00197
Epoch 8 (train)1.7s: train loss = 0.18876 = (mf)0.18659 + (embed)0.00217
Epoch 9 (train)2.0s: train loss = 0.18312 = (mf)0.18077 + (embed)0.00235
Epoch 10 (train)2.4s + (eval)0.4s: train loss = 0.17963 = (mf)0.17712 + (embed)0.00251, recall = 0.18415, ndcg = 0.39471, precision = 0.34475, map = 0.11200
Epoch 11 (train)2.5s: train loss = 0.17428 = (mf)0.17162 + (embed)0.00266
Epoch 12 (train)1.8s: train loss = 0.17207 = (mf)0.16926 + (embed)0.00281
Epoch 13 (train)1.7s: train loss = 0.16785 = (mf)0.16489 + (embed)0.00296
Epoch 14 (train)1.7s: train loss = 0.16748 = (mf)0.16435 + (embed)0.00313
Epoch 15 (train)1.6s + (eval)0.2s: train loss = 0.16055 = (mf)0.15724 + (embed)0.00331, recall = 0.19807, ndcg = 0.41482, precision = 0.36448, map = 0.12125
Epoch 16 (train)1.7s: train loss = 0.15802 = (mf)0.15454 + (embed)0.00348
Epoch 17 (train)1.7s: train loss = 0.15418 = (mf)0.15053 + (embed)0.00365
Epoch 18 (train)2.3s: train loss = 0.15146 = (mf)0.14762 + (embed)0.00384
Epoch 19 (train)2.4s: train loss = 0.14783 = (mf)0.14382 + (embed)0.00401
Epoch 20 (train)2.0s + (eval)0.2s: train loss = 0.14618 = (mf)0.14200 + (embed)0.00418, recall = 0.20394, ndcg = 0.43310, precision = 0.37402, map = 0.13032
Epoch 21 (train)1.8s: train loss = 0.14387 = (mf)0.13949 + (embed)0.00438
Epoch 22 (train)2.2s: train loss = 0.14073 = (mf)0.13617 + (embed)0.00456
Epoch 23 (train)1.7s: train loss = 0.13585 = (mf)0.13111 + (embed)0.00474
Epoch 24 (train)1.7s: train loss = 0.13340 = (mf)0.12846 + (embed)0.00495
Epoch 25 (train)1.9s + (eval)0.3s: train loss = 0.13018 = (mf)0.12503 + (embed)0.00514, recall = 0.20672, ndcg = 0.43799, precision = 0.38112, map = 0.13231
Epoch 26 (train)2.4s: train loss = 0.12877 = (mf)0.12342 + (embed)0.00535
Epoch 27 (train)2.4s: train loss = 0.12547 = (mf)0.11990 + (embed)0.00557
Epoch 28 (train)1.7s: train loss = 0.12075 = (mf)0.11498 + (embed)0.00578
Epoch 29 (train)1.7s: train loss = 0.12068 = (mf)0.11471 + (embed)0.00597
Epoch 30 (train)2.0s + (eval)0.2s: train loss = 0.11984 = (mf)0.11367 + (embed)0.00617, recall = 0.21183, ndcg = 0.45468, precision = 0.39608, map = 0.13923
Took 64.62246919799998 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Bacth Neg 1)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Batch 2

# %%
data = """
Epoch 1 (train)2.6s: train loss = 0.40600 = (mf)0.40559 + (embed)0.00041
Epoch 2 (train)1.8s: train loss = 0.27268 = (mf)0.27183 + (embed)0.00085
Epoch 3 (train)1.8s: train loss = 0.25265 = (mf)0.25156 + (embed)0.00109
Epoch 4 (train)1.8s: train loss = 0.23157 = (mf)0.23028 + (embed)0.00129
Epoch 5 (train)1.8s + (eval)0.2s: train loss = 0.21923 = (mf)0.21772 + (embed)0.00151, recall = 0.17226, ndcg = 0.38236, precision = 0.33415, map = 0.10513
Epoch 6 (train)2.3s: train loss = 0.20382 = (mf)0.20208 + (embed)0.00174
Epoch 7 (train)2.6s: train loss = 0.19614 = (mf)0.19419 + (embed)0.00195
Epoch 8 (train)2.2s: train loss = 0.19269 = (mf)0.19056 + (embed)0.00212
Epoch 9 (train)1.8s: train loss = 0.18461 = (mf)0.18232 + (embed)0.00228
Epoch 10 (train)1.8s + (eval)0.2s: train loss = 0.18133 = (mf)0.17889 + (embed)0.00243, recall = 0.18188, ndcg = 0.39019, precision = 0.34115, map = 0.11074
Epoch 11 (train)1.8s: train loss = 0.17871 = (mf)0.17612 + (embed)0.00259
Epoch 12 (train)1.8s: train loss = 0.17309 = (mf)0.17037 + (embed)0.00273
Epoch 13 (train)1.8s: train loss = 0.17056 = (mf)0.16768 + (embed)0.00288
Epoch 14 (train)2.4s: train loss = 0.16619 = (mf)0.16314 + (embed)0.00306
Epoch 15 (train)2.5s + (eval)0.4s: train loss = 0.16308 = (mf)0.15985 + (embed)0.00323, recall = 0.19783, ndcg = 0.41759, precision = 0.36543, map = 0.12284
Epoch 16 (train)2.0s: train loss = 0.15689 = (mf)0.15347 + (embed)0.00342
Epoch 17 (train)1.7s: train loss = 0.15292 = (mf)0.14932 + (embed)0.00360
Epoch 18 (train)1.7s: train loss = 0.15301 = (mf)0.14922 + (embed)0.00379
Epoch 19 (train)1.7s: train loss = 0.15014 = (mf)0.14616 + (embed)0.00398
Epoch 20 (train)1.7s + (eval)0.2s: train loss = 0.14312 = (mf)0.13893 + (embed)0.00419, recall = 0.20434, ndcg = 0.43331, precision = 0.37444, map = 0.13026
Epoch 21 (train)1.9s: train loss = 0.14092 = (mf)0.13654 + (embed)0.00439
Epoch 22 (train)2.4s: train loss = 0.13857 = (mf)0.13400 + (embed)0.00458
Epoch 23 (train)2.5s: train loss = 0.13625 = (mf)0.13147 + (embed)0.00477
Epoch 24 (train)1.9s: train loss = 0.13276 = (mf)0.12777 + (embed)0.00498
Epoch 25 (train)1.7s + (eval)0.2s: train loss = 0.13120 = (mf)0.12599 + (embed)0.00521, recall = 0.21132, ndcg = 0.44636, precision = 0.38865, map = 0.13621
Epoch 26 (train)1.7s: train loss = 0.12466 = (mf)0.11923 + (embed)0.00544
Epoch 27 (train)1.7s: train loss = 0.12369 = (mf)0.11804 + (embed)0.00566
Epoch 28 (train)1.7s: train loss = 0.12214 = (mf)0.11628 + (embed)0.00586
Epoch 29 (train)1.8s: train loss = 0.11875 = (mf)0.11268 + (embed)0.00607
Epoch 30 (train)2.4s + (eval)0.4s: train loss = 0.11803 = (mf)0.11173 + (embed)0.00630, recall = 0.21620, ndcg = 0.45299, precision = 0.39491, map = 0.13873
Took 60.73995294899987 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Bacth Neg 2)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Batch3

# %%
data = """
Epoch 1 (train)2.8s: train loss = 0.40876 = (mf)0.40836 + (embed)0.00040
Epoch 2 (train)1.7s: train loss = 0.27571 = (mf)0.27489 + (embed)0.00082
Epoch 3 (train)1.7s: train loss = 0.25726 = (mf)0.25621 + (embed)0.00105
Epoch 4 (train)1.7s: train loss = 0.24106 = (mf)0.23982 + (embed)0.00124
Epoch 5 (train)1.7s + (eval)0.2s: train loss = 0.22195 = (mf)0.22048 + (embed)0.00147, recall = 0.16671, ndcg = 0.36339, precision = 0.32068, map = 0.09855
Epoch 6 (train)1.7s: train loss = 0.20780 = (mf)0.20608 + (embed)0.00172
Epoch 7 (train)2.3s: train loss = 0.19541 = (mf)0.19344 + (embed)0.00197
Epoch 8 (train)2.5s: train loss = 0.18970 = (mf)0.18752 + (embed)0.00217
Epoch 9 (train)2.1s: train loss = 0.18462 = (mf)0.18227 + (embed)0.00234
Epoch 10 (train)1.8s + (eval)0.2s: train loss = 0.18178 = (mf)0.17929 + (embed)0.00249, recall = 0.18722, ndcg = 0.39982, precision = 0.34825, map = 0.11489
Epoch 11 (train)1.8s: train loss = 0.17988 = (mf)0.17725 + (embed)0.00262
Epoch 12 (train)1.8s: train loss = 0.17352 = (mf)0.17075 + (embed)0.00277
Epoch 13 (train)1.7s: train loss = 0.16982 = (mf)0.16691 + (embed)0.00291
Epoch 14 (train)1.7s: train loss = 0.16590 = (mf)0.16283 + (embed)0.00307
Epoch 15 (train)2.3s + (eval)0.4s: train loss = 0.16423 = (mf)0.16101 + (embed)0.00322, recall = 0.19818, ndcg = 0.41919, precision = 0.36681, map = 0.12312
Epoch 16 (train)2.5s: train loss = 0.15747 = (mf)0.15408 + (embed)0.00340
Epoch 17 (train)2.1s: train loss = 0.15573 = (mf)0.15214 + (embed)0.00358
Epoch 18 (train)1.7s: train loss = 0.15219 = (mf)0.14842 + (embed)0.00377
Epoch 19 (train)1.7s: train loss = 0.14922 = (mf)0.14527 + (embed)0.00396
Epoch 20 (train)1.7s + (eval)0.2s: train loss = 0.14479 = (mf)0.14064 + (embed)0.00415, recall = 0.20528, ndcg = 0.43293, precision = 0.37699, map = 0.13023
Epoch 21 (train)1.7s: train loss = 0.14220 = (mf)0.13786 + (embed)0.00434
Epoch 22 (train)1.7s: train loss = 0.13891 = (mf)0.13438 + (embed)0.00454
Epoch 23 (train)2.3s: train loss = 0.13673 = (mf)0.13201 + (embed)0.00473
Epoch 24 (train)2.4s: train loss = 0.13204 = (mf)0.12712 + (embed)0.00492
Epoch 25 (train)2.0s + (eval)0.2s: train loss = 0.13385 = (mf)0.12875 + (embed)0.00510, recall = 0.20388, ndcg = 0.43311, precision = 0.38017, map = 0.12982
Epoch 26 (train)1.7s: train loss = 0.13301 = (mf)0.12771 + (embed)0.00530
Epoch 27 (train)1.7s: train loss = 0.12799 = (mf)0.12250 + (embed)0.00549
Epoch 28 (train)1.7s: train loss = 0.12508 = (mf)0.11940 + (embed)0.00568
Epoch 29 (train)1.7s: train loss = 0.12244 = (mf)0.11654 + (embed)0.00590
Epoch 30 (train)1.7s + (eval)0.3s: train loss = 0.11970 = (mf)0.11360 + (embed)0.00609, recall = 0.21358, ndcg = 0.45023, precision = 0.39661, map = 0.13518
Took 59.02254175099995 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Bacth Neg 3)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Epoch 1

# %%
data = """
Epoch 1 (train)1.5s: train loss = 0.38765 = (mf)0.38723 + (embed)0.00042
Epoch 2 (train)138.5s: train loss = 0.24316 = (mf)0.24210 + (embed)0.00107
Epoch 3 (train)1.2s: train loss = 0.22033 = (mf)0.21882 + (embed)0.00151
Epoch 4 (train)1.2s: train loss = 0.20635 = (mf)0.20459 + (embed)0.00176
Epoch 5 (train)1.2s + (eval)0.2s: train loss = 0.19318 = (mf)0.19105 + (embed)0.00213, recall = 0.16151, ndcg = 0.36011, precision = 0.31262, map = 0.09734
Epoch 6 (train)1.2s: train loss = 0.17626 = (mf)0.17385 + (embed)0.00241
Epoch 7 (train)1.2s: train loss = 0.16343 = (mf)0.16070 + (embed)0.00273
Epoch 8 (train)1.2s: train loss = 0.15496 = (mf)0.15187 + (embed)0.00309
Epoch 9 (train)1.2s: train loss = 0.15278 = (mf)0.14939 + (embed)0.00338
Epoch 10 (train)1.5s + (eval)0.4s: train loss = 0.14659 = (mf)0.14304 + (embed)0.00355, recall = 0.18391, ndcg = 0.40036, precision = 0.34783, map = 0.11386
Epoch 11 (train)1.7s: train loss = 0.14637 = (mf)0.14264 + (embed)0.00373
Epoch 12 (train)1.7s: train loss = 0.14256 = (mf)0.13853 + (embed)0.00403
Epoch 13 (train)1.6s: train loss = 0.14114 = (mf)0.13691 + (embed)0.00423
Epoch 14 (train)1.3s: train loss = 0.13717 = (mf)0.13290 + (embed)0.00427
Epoch 15 (train)1.3s + (eval)0.2s: train loss = 0.13346 = (mf)0.12892 + (embed)0.00454, recall = 0.19325, ndcg = 0.41399, precision = 0.36151, map = 0.12009
Epoch 16 (train)1.2s: train loss = 0.13331 = (mf)0.12870 + (embed)0.00461
Epoch 17 (train)1.2s: train loss = 0.12678 = (mf)0.12182 + (embed)0.00497
Epoch 18 (train)1.2s: train loss = 0.12365 = (mf)0.11846 + (embed)0.00519
Epoch 19 (train)1.2s: train loss = 0.11907 = (mf)0.11370 + (embed)0.00538
Epoch 20 (train)1.4s + (eval)0.2s: train loss = 0.11713 = (mf)0.11146 + (embed)0.00567, recall = 0.19994, ndcg = 0.42799, precision = 0.37147, map = 0.12712
Epoch 21 (train)1.7s: train loss = 0.11628 = (mf)0.11045 + (embed)0.00583
Epoch 22 (train)1.9s: train loss = 0.11309 = (mf)0.10710 + (embed)0.00599
Epoch 23 (train)1.8s: train loss = 0.11393 = (mf)0.10773 + (embed)0.00619
Epoch 24 (train)1.8s: train loss = 0.10836 = (mf)0.10181 + (embed)0.00656
Epoch 25 (train)1.3s + (eval)0.2s: train loss = 0.10765 = (mf)0.10095 + (embed)0.00670, recall = 0.20699, ndcg = 0.43920, precision = 0.38431, map = 0.13103
Epoch 26 (train)1.2s: train loss = 0.10237 = (mf)0.09559 + (embed)0.00678
Epoch 27 (train)1.2s: train loss = 0.10251 = (mf)0.09521 + (embed)0.00730
Epoch 28 (train)1.2s: train loss = 0.10299 = (mf)0.09556 + (embed)0.00743
Epoch 29 (train)1.3s: train loss = 0.10056 = (mf)0.09302 + (embed)0.00755
Epoch 30 (train)1.3s + (eval)0.2s: train loss = 0.09782 = (mf)0.09014 + (embed)0.00769, recall = 0.21197, ndcg = 0.45361, precision = 0.39512, map = 0.13638
Took 179.5889785909999 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Epoch Neg 1)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Epoch 2

# %%
data = """
Epoch 1 (train)2.1s: train loss = 0.39771 = (mf)0.39732 + (embed)0.00040
Epoch 2 (train)136.6s: train loss = 0.25853 = (mf)0.25757 + (embed)0.00097
Epoch 3 (train)1.1s: train loss = 0.22711 = (mf)0.22578 + (embed)0.00133
Epoch 4 (train)1.2s: train loss = 0.20861 = (mf)0.20690 + (embed)0.00171
Epoch 5 (train)1.2s + (eval)0.2s: train loss = 0.19496 = (mf)0.19300 + (embed)0.00196, recall = 0.16314, ndcg = 0.36061, precision = 0.31516, map = 0.09468
Epoch 6 (train)1.2s: train loss = 0.18223 = (mf)0.17992 + (embed)0.00231
Epoch 7 (train)1.2s: train loss = 0.16578 = (mf)0.16324 + (embed)0.00254
Epoch 8 (train)1.1s: train loss = 0.15709 = (mf)0.15417 + (embed)0.00291
Epoch 9 (train)1.5s: train loss = 0.15480 = (mf)0.15164 + (embed)0.00315
Epoch 10 (train)1.7s + (eval)0.3s: train loss = 0.14998 = (mf)0.14639 + (embed)0.00358, recall = 0.18518, ndcg = 0.39683, precision = 0.34549, map = 0.11450
Epoch 11 (train)1.7s: train loss = 0.14287 = (mf)0.13911 + (embed)0.00376
Epoch 12 (train)1.5s: train loss = 0.13887 = (mf)0.13499 + (embed)0.00388
Epoch 13 (train)1.2s: train loss = 0.13918 = (mf)0.13522 + (embed)0.00396
Epoch 14 (train)1.1s: train loss = 0.14142 = (mf)0.13726 + (embed)0.00416
Epoch 15 (train)1.2s + (eval)0.2s: train loss = 0.13528 = (mf)0.13094 + (embed)0.00434, recall = 0.19665, ndcg = 0.42098, precision = 0.36766, map = 0.12296
Epoch 16 (train)1.2s: train loss = 0.13329 = (mf)0.12869 + (embed)0.00461
Epoch 17 (train)1.2s: train loss = 0.12366 = (mf)0.11880 + (embed)0.00485
Epoch 18 (train)1.1s: train loss = 0.12163 = (mf)0.11653 + (embed)0.00511
Epoch 19 (train)1.2s: train loss = 0.12229 = (mf)0.11697 + (embed)0.00531
Epoch 20 (train)1.2s + (eval)0.3s: train loss = 0.11731 = (mf)0.11167 + (embed)0.00565, recall = 0.20128, ndcg = 0.43365, precision = 0.37582, map = 0.12974
Epoch 21 (train)1.6s: train loss = 0.11586 = (mf)0.10994 + (embed)0.00592
Epoch 22 (train)1.6s: train loss = 0.11411 = (mf)0.10811 + (embed)0.00601
Epoch 23 (train)1.6s: train loss = 0.11080 = (mf)0.10453 + (embed)0.00627
Epoch 24 (train)1.4s: train loss = 0.11013 = (mf)0.10355 + (embed)0.00658
Epoch 25 (train)1.2s + (eval)0.2s: train loss = 0.10611 = (mf)0.09941 + (embed)0.00669, recall = 0.20750, ndcg = 0.43963, precision = 0.38250, map = 0.13142
Epoch 26 (train)1.2s: train loss = 0.10442 = (mf)0.09745 + (embed)0.00697
Epoch 27 (train)1.2s: train loss = 0.10378 = (mf)0.09665 + (embed)0.00713
Epoch 28 (train)1.2s: train loss = 0.10380 = (mf)0.09643 + (embed)0.00737
Epoch 29 (train)1.2s: train loss = 0.10061 = (mf)0.09297 + (embed)0.00763
Epoch 30 (train)1.2s + (eval)0.2s: train loss = 0.10008 = (mf)0.09236 + (embed)0.00772, recall = 0.21204, ndcg = 0.45208, precision = 0.39353, map = 0.13564
Took 176.03540829600024 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Epoch Neg 2)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Batch3

# %%
data = """
Epoch 1 (train)1.6s: train loss = 0.39201 = (mf)0.39160 + (embed)0.00041
Epoch 2 (train)143.7s: train loss = 0.24604 = (mf)0.24500 + (embed)0.00104
Epoch 3 (train)1.2s: train loss = 0.22015 = (mf)0.21872 + (embed)0.00143
Epoch 4 (train)1.2s: train loss = 0.20243 = (mf)0.20071 + (embed)0.00171
Epoch 5 (train)1.2s + (eval)0.2s: train loss = 0.18895 = (mf)0.18687 + (embed)0.00208, recall = 0.16833, ndcg = 0.37584, precision = 0.32598, map = 0.10124
Epoch 6 (train)1.2s: train loss = 0.17411 = (mf)0.17177 + (embed)0.00234
Epoch 7 (train)1.6s: train loss = 0.16754 = (mf)0.16491 + (embed)0.00263
Epoch 8 (train)1.6s: train loss = 0.16081 = (mf)0.15798 + (embed)0.00283
Epoch 9 (train)1.6s: train loss = 0.15673 = (mf)0.15364 + (embed)0.00309
Epoch 10 (train)1.4s + (eval)0.2s: train loss = 0.14908 = (mf)0.14576 + (embed)0.00332, recall = 0.18466, ndcg = 0.39866, precision = 0.34528, map = 0.11360
Epoch 11 (train)1.2s: train loss = 0.14763 = (mf)0.14409 + (embed)0.00354
Epoch 12 (train)1.2s: train loss = 0.14285 = (mf)0.13913 + (embed)0.00372
Epoch 13 (train)1.2s: train loss = 0.14065 = (mf)0.13659 + (embed)0.00407
Epoch 14 (train)1.2s: train loss = 0.13564 = (mf)0.13144 + (embed)0.00419
Epoch 15 (train)1.2s + (eval)0.2s: train loss = 0.13192 = (mf)0.12747 + (embed)0.00445, recall = 0.19567, ndcg = 0.41837, precision = 0.36341, map = 0.12235
Epoch 16 (train)1.2s: train loss = 0.13061 = (mf)0.12591 + (embed)0.00469
Epoch 17 (train)1.2s: train loss = 0.12703 = (mf)0.12214 + (embed)0.00488
Epoch 18 (train)1.3s: train loss = 0.12497 = (mf)0.11981 + (embed)0.00517
Epoch 19 (train)1.6s: train loss = 0.12223 = (mf)0.11679 + (embed)0.00544
Epoch 20 (train)1.7s + (eval)0.3s: train loss = 0.12057 = (mf)0.11493 + (embed)0.00565, recall = 0.20135, ndcg = 0.42975, precision = 0.37444, map = 0.12712
Epoch 21 (train)1.6s: train loss = 0.11666 = (mf)0.11076 + (embed)0.00590
Epoch 22 (train)1.2s: train loss = 0.11482 = (mf)0.10886 + (embed)0.00597
Epoch 23 (train)1.2s: train loss = 0.11237 = (mf)0.10625 + (embed)0.00612
Epoch 24 (train)1.2s: train loss = 0.10982 = (mf)0.10345 + (embed)0.00636
Epoch 25 (train)1.2s + (eval)0.2s: train loss = 0.10726 = (mf)0.10071 + (embed)0.00655, recall = 0.20444, ndcg = 0.43931, precision = 0.38324, map = 0.13079
Epoch 26 (train)1.2s: train loss = 0.10459 = (mf)0.09780 + (embed)0.00679
Epoch 27 (train)1.2s: train loss = 0.10309 = (mf)0.09608 + (embed)0.00701
Epoch 28 (train)1.2s: train loss = 0.10416 = (mf)0.09696 + (embed)0.00720
Epoch 29 (train)1.2s: train loss = 0.10112 = (mf)0.09378 + (embed)0.00734
Epoch 30 (train)1.4s + (eval)0.3s: train loss = 0.09843 = (mf)0.09084 + (embed)0.00759, recall = 0.21222, ndcg = 0.45012, precision = 0.39470, map = 0.13483
Took 182.91505738700016 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Epoch Neg 3)')
plt.legend()

# Show the plot
plt.show()
