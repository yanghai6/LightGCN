# %% [markdown]
# # Train curve

# %% [markdown]
# ## Batch 1

# %%
data = """
Epoch 1 (train)26.9s: train loss = 0.34689 = (mf)0.34643 + (embed)0.00046
Epoch 2 (train)25.7s: train loss = 0.13928 = (mf)0.13817 + (embed)0.00111
Epoch 3 (train)26.1s: train loss = 0.09501 = (mf)0.09350 + (embed)0.00151
Epoch 4 (train)26.2s: train loss = 0.07566 = (mf)0.07383 + (embed)0.00183
Epoch 5 (train)26.0s + (eval)1.8s: train loss = 0.06240 = (mf)0.06030 + (embed)0.00210, recall = 0.02529, ndcg = 0.04254, precision = 0.03645, map = 0.00958
Epoch 6 (train)25.6s: train loss = 0.05241 = (mf)0.05006 + (embed)0.00235
Epoch 7 (train)26.2s: train loss = 0.04657 = (mf)0.04399 + (embed)0.00258
Epoch 8 (train)26.2s: train loss = 0.04000 = (mf)0.03721 + (embed)0.00279
Epoch 9 (train)26.0s: train loss = 0.03447 = (mf)0.03149 + (embed)0.00299
Epoch 10 (train)25.8s + (eval)1.7s: train loss = 0.03302 = (mf)0.02983 + (embed)0.00318, recall = 0.02719, ndcg = 0.04880, precision = 0.04120, map = 0.01137
Epoch 11 (train)26.2s: train loss = 0.02857 = (mf)0.02521 + (embed)0.00336
Epoch 12 (train)26.1s: train loss = 0.02715 = (mf)0.02362 + (embed)0.00353
Epoch 13 (train)26.1s: train loss = 0.02390 = (mf)0.02022 + (embed)0.00368
Epoch 14 (train)25.8s: train loss = 0.02236 = (mf)0.01855 + (embed)0.00381
Epoch 15 (train)26.2s + (eval)1.5s: train loss = 0.01965 = (mf)0.01569 + (embed)0.00395, recall = 0.02790, ndcg = 0.05081, precision = 0.04320, map = 0.01181
Epoch 16 (train)26.2s: train loss = 0.01944 = (mf)0.01537 + (embed)0.00407
Epoch 17 (train)26.1s: train loss = 0.01755 = (mf)0.01336 + (embed)0.00419
Epoch 18 (train)25.8s: train loss = 0.01769 = (mf)0.01338 + (embed)0.00430
Epoch 19 (train)26.1s: train loss = 0.01580 = (mf)0.01139 + (embed)0.00441
Epoch 20 (train)26.2s + (eval)1.5s: train loss = 0.01633 = (mf)0.01182 + (embed)0.00451, recall = 0.02825, ndcg = 0.05028, precision = 0.04255, map = 0.01182
Epoch 21 (train)26.1s: train loss = 0.01360 = (mf)0.00899 + (embed)0.00460
Epoch 22 (train)25.7s: train loss = 0.01482 = (mf)0.01013 + (embed)0.00468
Epoch 23 (train)26.2s: train loss = 0.01350 = (mf)0.00875 + (embed)0.00475
Epoch 24 (train)26.1s: train loss = 0.01301 = (mf)0.00818 + (embed)0.00483
Epoch 25 (train)26.0s + (eval)1.9s: train loss = 0.01306 = (mf)0.00816 + (embed)0.00489, recall = 0.02766, ndcg = 0.05044, precision = 0.04210, map = 0.01183
Epoch 26 (train)25.7s: train loss = 0.01225 = (mf)0.00731 + (embed)0.00494
Epoch 27 (train)26.1s: train loss = 0.01249 = (mf)0.00749 + (embed)0.00499
Epoch 28 (train)26.2s: train loss = 0.01188 = (mf)0.00685 + (embed)0.00503
Epoch 29 (train)25.9s: train loss = 0.01191 = (mf)0.00683 + (embed)0.00508
Epoch 30 (train)25.9s + (eval)1.5s: train loss = 0.01129 = (mf)0.00617 + (embed)0.00512, recall = 0.02999, ndcg = 0.05283, precision = 0.04405, map = 0.01274
Took 791.404461155 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Bacth Neg 1)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Batch 2

# %%
data = """
Already create adjacency matrix.
Already normalize adjacency matrix.
Using xavier initialization.
Epoch 1 (train)26.8s: train loss = 0.34205 = (mf)0.34157 + (embed)0.00048
Epoch 2 (train)25.9s: train loss = 0.13996 = (mf)0.13884 + (embed)0.00111
Epoch 3 (train)26.3s: train loss = 0.09873 = (mf)0.09723 + (embed)0.00150
Epoch 4 (train)26.3s: train loss = 0.07610 = (mf)0.07428 + (embed)0.00182
Epoch 5 (train)26.3s + (eval)1.5s: train loss = 0.06353 = (mf)0.06144 + (embed)0.00209, recall = 0.02344, ndcg = 0.04146, precision = 0.03560, map = 0.00906
Epoch 6 (train)25.9s: train loss = 0.05528 = (mf)0.05295 + (embed)0.00233
Epoch 7 (train)26.1s: train loss = 0.04518 = (mf)0.04262 + (embed)0.00256
Epoch 8 (train)26.4s: train loss = 0.04015 = (mf)0.03738 + (embed)0.00278
Epoch 9 (train)26.4s: train loss = 0.03504 = (mf)0.03207 + (embed)0.00297
Epoch 10 (train)25.8s + (eval)1.9s: train loss = 0.03186 = (mf)0.02871 + (embed)0.00315, recall = 0.02663, ndcg = 0.04674, precision = 0.03940, map = 0.01067
Epoch 11 (train)26.1s: train loss = 0.02796 = (mf)0.02463 + (embed)0.00333
Epoch 12 (train)26.3s: train loss = 0.02587 = (mf)0.02237 + (embed)0.00350
Epoch 13 (train)26.3s: train loss = 0.02394 = (mf)0.02029 + (embed)0.00365
Epoch 14 (train)26.1s: train loss = 0.02368 = (mf)0.01988 + (embed)0.00380
Epoch 15 (train)26.3s + (eval)1.5s: train loss = 0.02081 = (mf)0.01689 + (embed)0.00392, recall = 0.02722, ndcg = 0.04720, precision = 0.04020, map = 0.01075
Epoch 16 (train)26.5s: train loss = 0.01883 = (mf)0.01477 + (embed)0.00406
Epoch 17 (train)26.7s: train loss = 0.01880 = (mf)0.01462 + (embed)0.00418
Epoch 18 (train)26.7s: train loss = 0.01687 = (mf)0.01258 + (embed)0.00428
Epoch 19 (train)26.1s: train loss = 0.01598 = (mf)0.01159 + (embed)0.00439
Epoch 20 (train)26.5s + (eval)1.5s: train loss = 0.01549 = (mf)0.01100 + (embed)0.00449, recall = 0.02918, ndcg = 0.05085, precision = 0.04305, map = 0.01199
Epoch 21 (train)26.4s: train loss = 0.01448 = (mf)0.00991 + (embed)0.00458
Epoch 22 (train)26.2s: train loss = 0.01480 = (mf)0.01014 + (embed)0.00466
Epoch 23 (train)25.7s: train loss = 0.01396 = (mf)0.00922 + (embed)0.00474
Epoch 24 (train)26.1s: train loss = 0.01350 = (mf)0.00868 + (embed)0.00482
Epoch 25 (train)26.1s + (eval)1.4s: train loss = 0.01228 = (mf)0.00740 + (embed)0.00488, recall = 0.02835, ndcg = 0.04903, precision = 0.04090, map = 0.01188
Epoch 26 (train)26.1s: train loss = 0.01177 = (mf)0.00683 + (embed)0.00494
Epoch 27 (train)25.7s: train loss = 0.01182 = (mf)0.00683 + (embed)0.00499
Epoch 28 (train)28.0s: train loss = 0.01209 = (mf)0.00705 + (embed)0.00504
Epoch 29 (train)26.0s: train loss = 0.01178 = (mf)0.00670 + (embed)0.00508
Epoch 30 (train)25.7s + (eval)1.8s: train loss = 0.01151 = (mf)0.00639 + (embed)0.00512, recall = 0.02954, ndcg = 0.05042, precision = 0.04225, map = 0.01204
Took 797.6003826690003 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Bacth Neg 2)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Batch 3

# %%
data = """
Already create adjacency matrix.
Already normalize adjacency matrix.
Using xavier initialization.
Epoch 1 (train)27.0s: train loss = 0.34690 = (mf)0.34643 + (embed)0.00047
Epoch 2 (train)25.8s: train loss = 0.14027 = (mf)0.13916 + (embed)0.00111
Epoch 3 (train)26.3s: train loss = 0.09668 = (mf)0.09517 + (embed)0.00151
Epoch 4 (train)26.3s: train loss = 0.07654 = (mf)0.07471 + (embed)0.00184
Epoch 5 (train)26.3s + (eval)1.5s: train loss = 0.06355 = (mf)0.06144 + (embed)0.00211, recall = 0.02582, ndcg = 0.04392, precision = 0.03780, map = 0.00989
Epoch 6 (train)26.0s: train loss = 0.05320 = (mf)0.05084 + (embed)0.00236
Epoch 7 (train)26.2s: train loss = 0.04653 = (mf)0.04394 + (embed)0.00259
Epoch 8 (train)26.3s: train loss = 0.04018 = (mf)0.03737 + (embed)0.00281
Epoch 9 (train)26.5s: train loss = 0.03434 = (mf)0.03134 + (embed)0.00301
Epoch 10 (train)25.9s + (eval)1.9s: train loss = 0.03201 = (mf)0.02880 + (embed)0.00320, recall = 0.02787, ndcg = 0.05015, precision = 0.04220, map = 0.01155
Epoch 11 (train)26.0s: train loss = 0.02771 = (mf)0.02433 + (embed)0.00338
Epoch 12 (train)26.2s: train loss = 0.02664 = (mf)0.02310 + (embed)0.00354
Epoch 13 (train)26.3s: train loss = 0.02434 = (mf)0.02065 + (embed)0.00369
Epoch 14 (train)26.2s: train loss = 0.02245 = (mf)0.01862 + (embed)0.00383
Epoch 15 (train)26.2s + (eval)1.5s: train loss = 0.01960 = (mf)0.01564 + (embed)0.00396, recall = 0.02865, ndcg = 0.04985, precision = 0.04275, map = 0.01149
Epoch 16 (train)26.5s: train loss = 0.01965 = (mf)0.01557 + (embed)0.00408
Epoch 17 (train)26.6s: train loss = 0.01796 = (mf)0.01375 + (embed)0.00420
Epoch 18 (train)26.1s: train loss = 0.01763 = (mf)0.01332 + (embed)0.00431
Epoch 19 (train)25.9s: train loss = 0.01571 = (mf)0.01130 + (embed)0.00441
Epoch 20 (train)26.3s + (eval)1.5s: train loss = 0.01541 = (mf)0.01089 + (embed)0.00452, recall = 0.02904, ndcg = 0.05068, precision = 0.04320, map = 0.01211
Epoch 21 (train)26.3s: train loss = 0.01367 = (mf)0.00906 + (embed)0.00461
Epoch 22 (train)26.2s: train loss = 0.01420 = (mf)0.00952 + (embed)0.00468
Epoch 23 (train)26.0s: train loss = 0.01328 = (mf)0.00853 + (embed)0.00475
Epoch 24 (train)26.5s: train loss = 0.01325 = (mf)0.00842 + (embed)0.00482
Epoch 25 (train)26.3s + (eval)1.5s: train loss = 0.01355 = (mf)0.00866 + (embed)0.00489, recall = 0.02954, ndcg = 0.05242, precision = 0.04345, map = 0.01259
Epoch 26 (train)26.1s: train loss = 0.01277 = (mf)0.00783 + (embed)0.00494
Epoch 27 (train)25.7s: train loss = 0.01267 = (mf)0.00768 + (embed)0.00499
Epoch 28 (train)26.2s: train loss = 0.01179 = (mf)0.00676 + (embed)0.00503
Epoch 29 (train)26.2s: train loss = 0.01153 = (mf)0.00646 + (embed)0.00507
Epoch 30 (train)26.0s + (eval)1.9s: train loss = 0.01135 = (mf)0.00624 + (embed)0.00512, recall = 0.02935, ndcg = 0.05284, precision = 0.04410, map = 0.01274
Took 796.507541938 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Bacth Neg 3)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Epoch 1

# %%
data = """
Epoch 1 (train)0.4s: train loss = 0.68394 = (mf)0.68391 + (embed)0.00003
Epoch 2 (train)81.0s: train loss = 0.64368 = (mf)0.64362 + (embed)0.00007
Epoch 3 (train)0.1s: train loss = 0.55683 = (mf)0.55667 + (embed)0.00015
Epoch 4 (train)0.1s: train loss = 0.43011 = (mf)0.42981 + (embed)0.00030
Epoch 5 (train)0.1s + (eval)0.1s: train loss = 0.32085 = (mf)0.32036 + (embed)0.00049, recall = 0.13117, ndcg = 0.09643, precision = 0.03148, map = 0.06472
Epoch 6 (train)0.1s: train loss = 0.25177 = (mf)0.25109 + (embed)0.00068
Epoch 7 (train)0.1s: train loss = 0.21745 = (mf)0.21660 + (embed)0.00085
Epoch 8 (train)0.1s: train loss = 0.17852 = (mf)0.17754 + (embed)0.00099
Epoch 9 (train)0.1s: train loss = 0.16502 = (mf)0.16391 + (embed)0.00111
Epoch 10 (train)0.1s + (eval)0.1s: train loss = 0.14807 = (mf)0.14685 + (embed)0.00122, recall = 0.16748, ndcg = 0.12103, precision = 0.04181, map = 0.07923
Epoch 11 (train)0.1s: train loss = 0.12745 = (mf)0.12612 + (embed)0.00132
Epoch 12 (train)0.1s: train loss = 0.10887 = (mf)0.10744 + (embed)0.00143
Epoch 13 (train)0.1s: train loss = 0.11277 = (mf)0.11125 + (embed)0.00153
Epoch 14 (train)0.1s: train loss = 0.10167 = (mf)0.10005 + (embed)0.00161
Epoch 15 (train)0.1s + (eval)0.1s: train loss = 0.09342 = (mf)0.09172 + (embed)0.00170, recall = 0.18848, ndcg = 0.13779, precision = 0.04738, map = 0.08974
Epoch 16 (train)0.1s: train loss = 0.08125 = (mf)0.07947 + (embed)0.00179
Epoch 17 (train)0.1s: train loss = 0.08028 = (mf)0.07842 + (embed)0.00187
Epoch 18 (train)0.1s: train loss = 0.07475 = (mf)0.07281 + (embed)0.00193
Epoch 19 (train)0.1s: train loss = 0.06816 = (mf)0.06616 + (embed)0.00200
Epoch 20 (train)0.1s + (eval)0.1s: train loss = 0.06667 = (mf)0.06460 + (embed)0.00207, recall = 0.19053, ndcg = 0.14463, precision = 0.04913, map = 0.09594
Epoch 21 (train)0.1s: train loss = 0.05935 = (mf)0.05721 + (embed)0.00214
Epoch 22 (train)0.1s: train loss = 0.06229 = (mf)0.06009 + (embed)0.00219
Epoch 23 (train)0.1s: train loss = 0.05629 = (mf)0.05402 + (embed)0.00226
Epoch 24 (train)0.1s: train loss = 0.05560 = (mf)0.05329 + (embed)0.00232
Epoch 25 (train)0.1s + (eval)0.1s: train loss = 0.05130 = (mf)0.04893 + (embed)0.00237, recall = 0.19309, ndcg = 0.15030, precision = 0.05183, map = 0.10040
Epoch 26 (train)0.1s: train loss = 0.04929 = (mf)0.04686 + (embed)0.00243
Epoch 27 (train)0.1s: train loss = 0.04521 = (mf)0.04274 + (embed)0.00247
Epoch 28 (train)0.1s: train loss = 0.04567 = (mf)0.04315 + (embed)0.00252
Epoch 29 (train)0.1s: train loss = 0.03873 = (mf)0.03617 + (embed)0.00256
Epoch 30 (train)0.1s + (eval)0.1s: train loss = 0.04293 = (mf)0.04031 + (embed)0.00262, recall = 0.19568, ndcg = 0.15248, precision = 0.05215, map = 0.10269
Took 84.656414584 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Epoch Neg 1)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Epoch 2

# %%
data = """
Already create adjacency matrix.
Already normalize adjacency matrix.
Using xavier initialization.
Epoch 1 (train)0.6s: train loss = 0.68347 = (mf)0.68345 + (embed)0.00003
Epoch 2 (train)77.2s: train loss = 0.64057 = (mf)0.64050 + (embed)0.00007
Epoch 3 (train)0.1s: train loss = 0.54189 = (mf)0.54174 + (embed)0.00016
Epoch 4 (train)0.1s: train loss = 0.40394 = (mf)0.40363 + (embed)0.00031
Epoch 5 (train)0.1s + (eval)0.1s: train loss = 0.30701 = (mf)0.30651 + (embed)0.00050, recall = 0.13175, ndcg = 0.09014, precision = 0.03100, map = 0.05708
Epoch 6 (train)0.1s: train loss = 0.24543 = (mf)0.24474 + (embed)0.00068
Epoch 7 (train)0.1s: train loss = 0.21785 = (mf)0.21702 + (embed)0.00083
Epoch 8 (train)0.1s: train loss = 0.19627 = (mf)0.19533 + (embed)0.00095
Epoch 9 (train)0.1s: train loss = 0.18254 = (mf)0.18147 + (embed)0.00107
Epoch 10 (train)0.1s + (eval)0.1s: train loss = 0.16730 = (mf)0.16613 + (embed)0.00118, recall = 0.16390, ndcg = 0.12253, precision = 0.03990, map = 0.08160
Epoch 11 (train)0.1s: train loss = 0.14460 = (mf)0.14331 + (embed)0.00128
Epoch 12 (train)0.1s: train loss = 0.12604 = (mf)0.12465 + (embed)0.00139
Epoch 13 (train)0.1s: train loss = 0.11809 = (mf)0.11661 + (embed)0.00148
Epoch 14 (train)0.1s: train loss = 0.10488 = (mf)0.10330 + (embed)0.00157
Epoch 15 (train)0.1s + (eval)0.1s: train loss = 0.09792 = (mf)0.09626 + (embed)0.00166, recall = 0.18686, ndcg = 0.13738, precision = 0.04610, map = 0.09018
Epoch 16 (train)0.1s: train loss = 0.09091 = (mf)0.08917 + (embed)0.00174
Epoch 17 (train)0.1s: train loss = 0.08536 = (mf)0.08354 + (embed)0.00181
Epoch 18 (train)0.1s: train loss = 0.07509 = (mf)0.07320 + (embed)0.00189
Epoch 19 (train)0.1s: train loss = 0.07613 = (mf)0.07415 + (embed)0.00197
Epoch 20 (train)0.1s + (eval)0.1s: train loss = 0.06856 = (mf)0.06652 + (embed)0.00203, recall = 0.19482, ndcg = 0.14335, precision = 0.04913, map = 0.09414
Epoch 21 (train)0.1s: train loss = 0.06341 = (mf)0.06131 + (embed)0.00210
Epoch 22 (train)0.1s: train loss = 0.06362 = (mf)0.06146 + (embed)0.00216
Epoch 23 (train)0.1s: train loss = 0.06168 = (mf)0.05947 + (embed)0.00221
Epoch 24 (train)0.1s: train loss = 0.05372 = (mf)0.05145 + (embed)0.00227
Epoch 25 (train)0.1s + (eval)0.1s: train loss = 0.05159 = (mf)0.04926 + (embed)0.00233, recall = 0.19844, ndcg = 0.14939, precision = 0.05183, map = 0.09894
Epoch 26 (train)0.1s: train loss = 0.04978 = (mf)0.04739 + (embed)0.00239
Epoch 27 (train)0.1s: train loss = 0.05155 = (mf)0.04911 + (embed)0.00244
Epoch 28 (train)0.1s: train loss = 0.04628 = (mf)0.04379 + (embed)0.00250
Epoch 29 (train)0.1s: train loss = 0.04400 = (mf)0.04145 + (embed)0.00254
Epoch 30 (train)0.1s + (eval)0.1s: train loss = 0.04408 = (mf)0.04149 + (embed)0.00258, recall = 0.19715, ndcg = 0.14983, precision = 0.05231, map = 0.09907
Took 80.94138780699996 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Epoch Neg 2)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Epoch 3

# %%
data = """
Already create adjacency matrix.
Already normalize adjacency matrix.
Using xavier initialization.
Epoch 1 (train)0.5s: train loss = 0.68347 = (mf)0.68344 + (embed)0.00003
Epoch 2 (train)77.9s: train loss = 0.63843 = (mf)0.63836 + (embed)0.00007
Epoch 3 (train)0.1s: train loss = 0.54513 = (mf)0.54497 + (embed)0.00015
Epoch 4 (train)0.1s: train loss = 0.40719 = (mf)0.40688 + (embed)0.00030
Epoch 5 (train)0.1s + (eval)0.1s: train loss = 0.30654 = (mf)0.30605 + (embed)0.00050, recall = 0.13287, ndcg = 0.09094, precision = 0.03148, map = 0.05853
Epoch 6 (train)0.1s: train loss = 0.24275 = (mf)0.24208 + (embed)0.00068
Epoch 7 (train)0.1s: train loss = 0.20582 = (mf)0.20498 + (embed)0.00084
Epoch 8 (train)0.1s: train loss = 0.18492 = (mf)0.18395 + (embed)0.00097
Epoch 9 (train)0.1s: train loss = 0.16199 = (mf)0.16091 + (embed)0.00108
Epoch 10 (train)0.1s + (eval)0.1s: train loss = 0.16477 = (mf)0.16359 + (embed)0.00119, recall = 0.16694, ndcg = 0.12121, precision = 0.04181, map = 0.07948
Epoch 11 (train)0.1s: train loss = 0.14348 = (mf)0.14220 + (embed)0.00128
Epoch 12 (train)0.1s: train loss = 0.13190 = (mf)0.13052 + (embed)0.00138
Epoch 13 (train)0.1s: train loss = 0.11584 = (mf)0.11437 + (embed)0.00148
Epoch 14 (train)0.1s: train loss = 0.10896 = (mf)0.10740 + (embed)0.00156
Epoch 15 (train)0.1s + (eval)0.1s: train loss = 0.09647 = (mf)0.09483 + (embed)0.00164, recall = 0.18679, ndcg = 0.13875, precision = 0.04642, map = 0.09329
Epoch 16 (train)0.1s: train loss = 0.08719 = (mf)0.08546 + (embed)0.00173
Epoch 17 (train)0.1s: train loss = 0.08197 = (mf)0.08017 + (embed)0.00180
Epoch 18 (train)0.1s: train loss = 0.07717 = (mf)0.07530 + (embed)0.00187
Epoch 19 (train)0.1s: train loss = 0.07546 = (mf)0.07353 + (embed)0.00193
Epoch 20 (train)0.1s + (eval)0.1s: train loss = 0.07278 = (mf)0.07078 + (embed)0.00200, recall = 0.19620, ndcg = 0.14433, precision = 0.04976, map = 0.09550
Epoch 21 (train)0.1s: train loss = 0.06823 = (mf)0.06615 + (embed)0.00207
Epoch 22 (train)0.1s: train loss = 0.05756 = (mf)0.05541 + (embed)0.00214
Epoch 23 (train)0.1s: train loss = 0.05567 = (mf)0.05346 + (embed)0.00220
Epoch 24 (train)0.1s: train loss = 0.05561 = (mf)0.05334 + (embed)0.00227
Epoch 25 (train)0.1s + (eval)0.1s: train loss = 0.05059 = (mf)0.04828 + (embed)0.00232, recall = 0.20229, ndcg = 0.14609, precision = 0.05294, map = 0.09421
Epoch 26 (train)0.1s: train loss = 0.05171 = (mf)0.04934 + (embed)0.00237
Epoch 27 (train)0.1s: train loss = 0.04891 = (mf)0.04647 + (embed)0.00244
Epoch 28 (train)0.1s: train loss = 0.04808 = (mf)0.04560 + (embed)0.00248
Epoch 29 (train)0.1s: train loss = 0.04545 = (mf)0.04291 + (embed)0.00254
Epoch 30 (train)0.1s + (eval)0.1s: train loss = 0.04665 = (mf)0.04407 + (embed)0.00258, recall = 0.20412, ndcg = 0.15172, precision = 0.05358, map = 0.10020
Took 81.55505591400015 seconds for training.
"""

# Adjusting the parsing method for the provided data
import re

# Parsing the data
train_loss = []
mf = []
embed = []

for line in data.split('\n'):
    if "train loss" in line:
        # Extracting train loss, mf, and embed values using regular expressions
        loss_match = re.search(r'train loss = ([0-9.]+)', line)
        mf_match = re.search(r'\(mf\)([0-9.]+)', line)
        embed_match = re.search(r'\(embed\)([0-9.]+)', line)

        if loss_match and mf_match and embed_match:
            train_loss.append(float(loss_match.group(1)))
            mf.append(float(mf_match.group(1)))
            embed.append(float(embed_match.group(1)))

# train_loss, mf, embed

# %%
import matplotlib.pyplot as plt

# Number of epochs
epochs = list(range(1, len(train_loss) + 1))

# Creating the plot
plt.figure(figsize=(12, 6))

# Plotting training loss, validation loss, and embeddings
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, mf, label='MF Loss')
plt.plot(epochs, embed, label='Embedding Magnitude', linestyle='--')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss / Embedding Magnitude')
plt.title('Training and Validation Loss Curve with Embedding Magnitude (Epoch Neg 3)')
plt.legend()

# Show the plot
plt.show()
